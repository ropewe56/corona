# %%
import sys,os
import numpy as np
import pylab as plt

# %%
drki = np.load("RKI/rki.npy")
djsh = np.load("JohnsHopkins/johns_hopkins.npy")

plt.plot(drki[:,0])
plt.plot(djsh[:,0])

plt.figure()
plt.plot(drki[:,1])
plt.plot(djsh[:,1])
